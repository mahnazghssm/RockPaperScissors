# %%
class RockPaperScissors:
    pass

# %% [markdown]
# - get player choice
# - get computer choice
# - get winner
# - print winner
# - play again?

# %%
class RockPaperScissors:
    def __init__(self, name):
        self.name = name
        self.choices = ["rock", "paper", "scissors"]

    # get_player_choice
    # get_computer_choice
    # decide_winner
    # play

# %%
class RockPaperScissors:
    def __init__(self, name):
        self.name = name
        self.choices = ["rock", "paper", "scissors"]

    def get_player_choice(self):
        user_choice = input(f"Enter your choice({self.choices}): ")
        print(user_choice)
        if user_choice.lower() in self.choices:
            return user_choice
        
        print(f" invalid choice, you must select from {self.choices}.")
        return self.get_player_choice

    def play(self):
        user_choice = self.get_player_choice()

# %%
game = RockPaperScissors("mahnaz")

# %%
game.play()
# Out:
# rock

# %%
import random


class RockPaperScissors:
    def __init__(self, name):
        self.name = name
        self.choices = ["rock", "paper", "scissors"]

    def get_player_choice(self):
        user_choice = input(f"Enter your choice({self.choices}): ")
        if user_choice.lower() in self.choices:
            return user_choice
        
        print(f" invalid choice, you must select from {self.choices}.")
        return self.get_player_choice
    
    def get_computer_choice(self):
        return random.choice(self.choices)

    def play(self):
        user_choice = self.get_player_choice()

# %%
game.play()
# Out:
# rock

# %%
import random


class RockPaperScissors:
    def __init__(self, name):
        self.name = name
        self.choices = ["rock", "paper", "scissors"]

    def get_player_choice(self):
        user_choice = input(f"Enter your choice({self.choices}): ")
        if user_choice.lower() in self.choices:
            return user_choice.lower()
        
        print(f" invalid choice, you must select from {self.choices}.")
        return self.get_player_choice()
    
    def get_computer_choice(self):
        return random.choice(self.choices)

    def play(self):
        user_choice = self.get_player_choice()
        computer_choice = self.get_computer_choice()
        print(user_choice, computer_choice)

# %%
game = RockPaperScissors("mahnaz")
game.play()
# Out:
# rock paper

# %%
import random


class RockPaperScissors:
    def __init__(self, name):
        self.name = name
        self.choices = ["rock", "paper", "scissors"]

    def get_player_choice(self):
        user_choice = input(f"Enter your choice({self.choices}): ")
        if user_choice.lower() in self.choices:
            return user_choice.lower()
        
        print(f" invalid choice, you must select from {self.choices}.")
        return self.get_player_choice()
    
    def get_computer_choice(self):
        return random.choice(self.choices)
    
    def play(self):
        user_choice = self.get_player_choice()
        computer_choice = self.get_computer_choice()
        self.decide_winner(user_choice, computer_choice)

# %%
import random


class RockPaperScissors:
    def __init__(self, name):
        self.name = name
        self.choices = ["rock", "paper", "scissors"]

    def get_player_choice(self):
        user_choice = input(f"Enter your choice({self.choices}): ")
        if user_choice.lower() in self.choices:
            return user_choice.lower()
        
        print(f" invalid choice, you must select from {self.choices}.")
        return self.get_player_choice()
    
    def get_computer_choice(self):
        return random.choice(self.choices)
    
    def decide_winner(self, user_choice, computer_choice):
        if user_choice == computer_choice:
            return "It is a Tie!"
        
        win_combinations = [("rock", "scissors"), ("paper", "rock"), ("scissors", "paper")]
        for win in win_combinations:
            if (user_choice == win[0]) & (computer_choice == win[1]):
                return "Congratulations! You won"
            
        return "Oh no! The computer won!"

    def play(self):
        user_choice = self.get_player_choice()
        computer_choice = self.get_computer_choice()
        winner_msg = self.decide_winner(user_choice, computer_choice)
        print(f"User choice: {user_choice}\n")
        print(f"Computer choice: {computer_choice}\n")
        print(winner_msg)

# %%
game.play()
# Out:
# paper rock

# %%
game = RockPaperScissors("mahnaz")


while True:
    game.play()

    continue_game = input("Do you want to play again? (Enter any key to play again, Enter 'q' to quit!) ")
    if continue_game.lower() == "q":
        print("Goodbye")
        break
# Out:
# User choice: rock
#
# Computer choice: paper
#
# Oh no! The computer won!
# Goodbye

# %%
if __name__ == "__main__":
    game = RockPaperScissors("mahnaz")


while True:
    game.play()

    continue_game = input("Do you want to play again? (Enter any key to play again, Enter 'q' to quit!) ")
    if continue_game.lower() == "q":
        print("Goodbye")
        break
